# %%
import requests

# %%
n = 115

# %%
response = requests.get(f"http://localhost:5000/sq/{n}")

# %%
response = requests.get("http://localhost:5000/cube/manolo89", params={"n": 4}, headers={"password": "pepito88"})

# %%
SaaS

# %%
response.json()
# Out:
# {'n': 4, 'square': 64}

# %%
response.status_code
# Out:
# 200

# %%
response.json().get("sq")
# Out:
# 13225

# %%
requests.get("http://localhost:5000/square", params={"n": 8}).json()
# Out:
# {'n': 8, 'square': 64}

# %%
hash("ironhack2021")
# Out:
# 3884579944254060314

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
bnw = np.random.randint(0, 255, (10, 10))

# %%
plt.imshow(bnw, cmap="gray")

# %%
col = np.random.randint(0, 255, (10, 10, 3))

# %%
col = plt.imshow(bnw, )

# %%
d = plt.imread("./week_06/ddd.jpeg")

# %%
d.shape
# Out:
# (225, 225, 3)

# %%
plt.imshow(d)

# %%
ojo = d[25:100, 80:150]

# %%
ojo.shape
# Out:
# (75, 70, 3)

# %%
plt.imshow(ojo)

# %%
ojo.shape
# Out:
# (75, 70, 3)

# %%
ojo.size
# Out:
# 15750

# %%
a3 bb c4 56

# %%
ojo
# Out:
# array([[[255, 222, 125],
#         [255, 222, 125],
#         [255, 222, 125],
#         ...,
#         [ 58,  59, 113],
#         [ 47,  49, 106],
#         [ 11,  16,  71]],
#
#        [[255, 222, 125],
#         [255, 222, 125],
#         [255, 222, 125],
#         ...,
#         [ 51,  50,  94],
#         [ 42,  43,  99],
#         [ 20,  22,  81]],
#
#        [[255, 222, 125],
#         [255, 222, 125],
#         [255, 222, 125],
#         ...,
#         [ 50,  44,  80],
#         [ 34,  29,  83],
#         [ 52,  52, 114]],
#
#        ...,
#
#        [[255, 220, 129],
#         [255, 220, 129],
#         [255, 220, 129],
#         ...,
#         [255, 219, 125],
#         [255, 219, 122],
#         [255, 219, 122]],
#
#        [[255, 220, 129],
#         [255, 220, 129],
#         [255, 220, 129],
#         ...,
#         [255, 219, 123],
#         [255, 219, 122],
#         [255, 219, 120]],
#
#        [[255, 220, 129],
#         [255, 220, 129],
#         [255, 220, 129],
# ...

# %%
requests.get("https://api.wheretheiss.at/v1/satellites/25544?units=miles").json()
# Out:
# {'name': 'iss',
#  'id': 25544,
#  'latitude': -12.952619448422,
#  'longitude': 130.53015876307,
#  'altitude': 263.17158876601,
#  'velocity': 17131.233758562,
#  'visibility': 'daylight',
#  'footprint': 2811.9511236038,
#  'timestamp': 1631778160,
#  'daynum': 2459473.8212963,
#  'solar_lat': 2.5105578061683,
#  'solar_lon': 63.04609036645,
#  'units': 'miles'}
